# %% [markdown]
# <a href="https://colab.research.google.com/github/Anna-Bialer-Tsypin/Jhon-Bryce/blob/main/Washington_Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from plotly import express as px

# %%
# set plotly as backend for pd
pd.options.plotting.backend = "plotly"

# %%
data_path = "https://storage.googleapis.com/edulabs-public-datasets/housing_washington.csv"

# %%
df = pd.read_csv(data_path)

# %%
df.head(2)
# Out:
#       Unnamed: 0          id  \
# 0          20462  7049751307
# 1          20542  7049730858
# 2          20554  7049730743
# 3          20568  7045876523
# 4          20912  7045876148
# ...          ...         ...
# 2497       32935  7049612244
# 2498       32936  7049612210
# 2499       32937  7040958325
# 2500       32938  7049611505
# 2501       32940  7049611451
#
#                                                     url          region  \
# 0     https://washingtondc.craigslist.org/nva/apa/d/...  washington, DC
# 1     https://washingtondc.craigslist.org/mld/apa/d/...  washington, DC
# 2     https://washingtondc.craigslist.org/nva/apa/d/...  washington, DC
# 3     https://washingtondc.craigslist.org/doc/apa/d/...  washington, DC
# 4     https://washingtondc.craigslist.org/doc/apa/d/...  washington, DC
# ...                                                 ...             ...
# 2497  https://washingtondc.craigslist.org/mld/apa/d/...  washington, DC
# ...

# %%
df['price'].hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
np.log(df['price']+1).hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
